# %%
l1= "tyson and bruno"
l1.capitalize()
# Out:
# 'Tyson and bruno'

# %%
l1= "tyson and BRUNO"
l1.casefold()
# Out:
# 'tyson and bruno'

# %% [markdown]
# dooubt

# %%
l1= "tyson and BRUNO"
l1.center(21,)
# Out:
# '   tyson and BRUNO   '

# %%
l1= "tyson and BRUNO"
l1.count('a')
# Out:
# 1

# %% [markdown]
# doubt

# %%
l1= "tyson and BRUNO"
l1.encode()
# Out:
# b'tyson and BRUNO'

# %%
l1= "tyson and BRUNO"
l1.endswith("BRUNO")
# Out:
# True

# %%
l1= "tyson\t and BRUNO"
l1.expandtabs()
# Out:
# 'tyson    and BRUNO'

# %%
l1= "tyson and BRUNO"
l1.find("and")
# Out:
# 6

# %%
l1= "{} tyson and BRUNO {}"
l1.format('Both my dog are',"for real")
# Out:
# 'Both my dog are tyson and BRUNO for real'

# %%
l1= "I am {Name} and my type is {type}"
l1.format_map({"Name":"harsh","type":"just diffrent"})
# Out:
# 'I am harsh and my type is just diffrent'

# %%
l1= "tyson and BRUNO"
l1.index("o")
# Out:
# 3

# %%
l1= "99"
l1.isalnum()
# Out:
# True

# %%
l1= "tysonandBRUNO"
l1.isalpha()
# Out:
# True

# %%
l1= "tyson and BRUNO, ब्रूनो"
l1.isascii()
# Out:
# False

# %% [markdown]
# # only need for pure numeric value for calculations

# %%
l1= "12544"
l1.isdecimal()
# Out:
# True

# %% [markdown]
# # for all the other numeric characters as well

# %%
l1= "125/34"
l1.isdigit()
# Out:
# False

# %%
l1= "_tysonandBRUNO2"
l1.isidentifier()
# Out:
# True

# %%
l1= "tyson and bruno"
l1.islower()
# Out:
# True

# %%
l1= "tyson and BRUNO"
l1.isnumeric()
# Out:
# False

# %% [markdown]
# # checks if all the characters are printable or not (like \t \n etc)

# %%
l1= "tyson \n and BRUNO"
l1.isprintable()
# Out:
# False

# %% [markdown]
# # only accepts whitespace characters like \t \n and ' ' other spacing characters

# %%
l1= "\t \n"
l1.isspace()
# Out:
# True

# %%
l1= " Bruno"
l1.istitle()
# Out:
# True

# %%
l1= "TYSON AND BRUNO"
l1.isupper()
# Out:
# True

# %%
l1= ["tyson", "and" ,"BRUNO"]
"".join(l1)
# Out:
# 'tysonandBRUNO'

# %%
l1= "tyson and BRUNO"
l1.ljust(20)
# Out:
# 'tyson and BRUNO     '

# %%
l1= "tyson and BRUNO"
l1.lower()
# Out:
# 'tyson and bruno'

# %%
l1= "  tyson and BRUNO"
l1.lstrip()
# Out:
# 'tyson and BRUNO'

# %%
l1= "tyson and BRUNO   "
l1.rstrip()
# Out:
# 'tyson and BRUNO'

# %% [markdown]
# # .maketrans(x,y)
# # x- string of the character you want to replace
# # y- same lenght string you want to replace with

# %%
l1= "tyson and BRUNO"
b1=l1.maketrans("Bcd","342")
print(l1.translate(b1))
# Out:
# tyson an2 3RUNO

# %% [markdown]
# # split at the first occurence

# %%
l1= "tyson and BRUNO"
l1.partition(" ")
# Out:
# ('tyson', ' ', 'and BRUNO')

# %%
l1= "tyson and BRUNO"
l1.removeprefix('tys')
# Out:
# 'on and BRUNO'

# %%
l1= "tyson and BRUNO"
l1.removesuffix('UNO')
# Out:
# 'tyson and BR'

# %%
l1= "tyson and BRUNO"
l1.rfind("and")
# Out:
# 6

# %%
l1.replace("and","but")
# Out:
# 'tyson but BRUNO'

# %% [markdown]
# # it is to find the substring las occurence

# %%
l1= "tyson and BRUNO"
l1.rindex("son")
# Out:
# 2

# %% [markdown]
# # adds extra no. of space start of the string or left of the string shifts the string as required

# %%
l1= "tyson and BRUNO"
l1.rjust(19)
# Out:
# '    tyson and BRUNO'

# %%
l1= "tyson and BRUNO"
l1.split()
# Out:
# ['tyson', 'and', 'BRUNO']

# %% [markdown]
# # Splits by libebreak

# %%
l1= "tyson\nand\nBRUNO"
print(l1)
l1.splitlines()
# Out:
# tyson
# and
# BRUNO
# ['tyson', 'and', 'BRUNO']

# %% [markdown]
# # checks the starting string

# %%
l1.startswith('B')
# Out:
# False

# %% [markdown]
# # It just swap case lower to upper and vise-versa

# %%
l1= "tyson and BRUNO"
l1.swapcase()
# Out:
# 'TYSON AND bruno'

# %% [markdown]
# # only first letter into capital and rest smallercase

# %%
l1.title()
# Out:
# 'Tyson And Bruno'

# %% [markdown]
# # fills zeros in front of the string if the input is greater than this string itself

# %%
l1= "tyson and BRUNO"
l1.zfill(20)
# Out:
# '00000tyson and BRUNO'
